# %%
# !git clone https://github.com/duongduc2908/do_an.git
# Out:
# Cloning into 'do_an'...
# remote: Enumerating objects: 291, done.
# remote: Counting objects: 100% (291/291), done.
# remote: Compressing objects: 100% (230/230), done.
# remote: Total 291 (delta 31), reused 277 (delta 25), pack-reused 0
# Receiving objects: 100% (291/291), 27.03 MiB | 30.54 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
# %cd do_an
# Out:
# /content/do_an

# %%
# %cd rtsp-simple-server/
# Out:
# /content/do_an/rtsp-simple-server

# %%
# !sudo docker run --rm -it -v $PWD/rtsp-simple-server.yml:/rtsp-simple-server.yml -p 8554:8554 aler9/rtsp-simple-server
# Out:
# docker: Cannot connect to the Docker daemon at unix:///var/run/docker.sock. Is the docker daemon running?.
# See 'docker run --help'.

# %%
! sudo apt update
! sudo apt install apt-transport-https ca-certificates curl software-properties-common
! curl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo apt-key add -
! sudo add-apt-repository "deb [arch=amd64] https://download.docker.com/linux/ubuntu bionic stable"
! sudo apt update
! sudo apt install docker-ce
! sudo systemctl status docker

# %%
! sudo /etc/init.d/docker start
# Out:
#  * Starting Docker: docker
#    ...done.

# %%
! sudo service docker status
# Out:
#  * Docker is running

# %%
# !sudo dockerd

# %%
# !sudo service docker stop
# Out:
#  * Stopping Docker: docker
# Program process in pidfile '/var/run/docker-ssd.pid', 1 process(es), refused to die.

# %%
# !docker run --runtime=nvidia -it --rm -p 8081:8081 aecampos/docker-colab-local:latest
# Out:
# docker: Cannot connect to the Docker daemon at unix:///var/run/docker.sock. Is the docker daemon running?.
# See 'docker run --help'.
